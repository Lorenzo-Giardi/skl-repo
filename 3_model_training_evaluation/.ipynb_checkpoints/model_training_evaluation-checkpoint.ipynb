# %% [markdown]
# # Model Training and Evaluation
# Three main steps:
# * Training
# * Validation (hyper-parameters tuning)
# * Test (model selection)
# If the dataset is big enough, then each step can be performed on a separate set of data. A common alternative is to use the same data for both training and validation by applying k-fold cross-validation.

# %% [markdown]
# ### Imports

# %%
import os
import numpy as np
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data

# %%
data_path = '/home/lorenzo/skl-repo/0_data/california_housing.csv'
df = pd.read_csv(data_path)
X = df.drop('median_house_value', axis=1)
y = df['median_house_value']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size = 0.2, random_state=3542)
print(f'Train set length: {len(train_X)}')
print(f'Test set length: {len(test_X)}')
# Out:
# Train set length: 16512
# Test set length: 4128

# %%
from sklearn.base import BaseEstimator, TransformerMixin

rooms_ix, beds_ix, pop_ix, hh_ix = 3,4,5,6

class CombineAttributes(BaseEstimator, TransformerMixin):
    
    def __init__(self, add_bedrooms_per_room = True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        rooms_per_hh = X[:, rooms_ix] / X[:, hh_ix]
        avg_hh_size = X[:, pop_ix] / X[:, hh_ix]
        if self.add_bedrooms_per_room:
            beds_per_room = X[:, beds_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_hh, avg_hh_size, beds_per_room]
        else:
            return np.c_[X, rooms_per_hh, avg_hh_size]

# %%
trainX_cat = train_X.select_dtypes(exclude=np.number)
trainX_num = train_X.select_dtypes(include=np.number)
testX_cat = test_X.select_dtypes(exclude=np.number)
testX_num = test_X.select_dtypes(include=np.number)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

num_columns = list(trainX_num.columns)
cat_columns = list(trainX_cat.columns)

# pipeline for numerical columns
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy = 'median')),
    ('cstm_attribs', CombineAttributes()),
    ('std_scaler', StandardScaler()),
])

# pipeline for categorical columns
cat_pipeline = Pipeline([
    ('onehot_enc', OneHotEncoder()),
])

# full pipeline
full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_columns),
    ('cat', cat_pipeline, cat_columns),
])

# %%
# Apply pipeline transformation to features (X)
train_X = full_pipeline.fit_transform(train_X)
test_X = full_pipeline.transform(test_X)

# Convert target to numpy array (y)
train_y, test_y = train_y.values, test_y.values

# %% [markdown]
# ### Simple evaluation on test set

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_reg = LinearRegression()
lin_reg.fit(train_X, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_pred = lin_reg.predict(test_X)
lin_mse = mean_squared_error(test_y, lin_pred)
lin_rmse = np.sqrt(lin_mse)
print(f'Linear regression RMSE: {lin_rmse}')
# Out:
# Linear regression RMSE: 69877.91447040191

# %%
plt.scatter(test_y, lin_pred, alpha = 0.1)
plt.plot([0,500000], [0,500000], color='k', linestyle='-', linewidth=1)
plt.ylim(0, 700000)
plt.xlim(0, 700000)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

rf = RandomForestRegressor(n_jobs=-1)
rf.fit(train_X, train_y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_pred = rf.predict(test_X)
rf_mse = mean_squared_error(test_y, rf_pred)
rf_rmse = np.sqrt(rf_mse)
print(f'Random forest RMSE: {rf_rmse}')
# Out:
# Random forest RMSE: 50773.86551154917

# %%
plt.scatter(test_y, rf_pred, alpha = 0.1)
plt.plot([0,500000], [0,500000], color='k', linestyle='-', linewidth=1)
plt.ylim(0, 700000)
plt.xlim(0, 700000)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

# %% [markdown]
# ### Cross-validated model evaluation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf, train_X, train_y, scoring = "neg_mean_squared_error", cv=10, n_jobs=-1)
rf_cv_rmse = np.sqrt(-scores)

# %%
print(f'Random forest CV scores: \n{rf_cv_rmse}')
print(f'\nRandom forest mean CV score: {np.mean(rf_cv_rmse)}')
# Out:
# Random forest CV scores:
# [55164.29571949 46334.01994039 48975.19288079 49277.97479742
#  50495.5145756  49040.85439967 50762.04962007 48248.64703053
#  49340.60902069 49677.31883393]
#
# Random forest mean CV score: 49731.647681856586

# %% [markdown]
# ### Hyper-parameters tuning
#
# Exhaustive **grid search**:

# %%
from sklearn.model_selection import GridSearchCV

parameters_grid = [
    {'n_estimators': [10, 100], 'min_samples_leaf':[1, 3, 5], 'max_depth':[None, 5, 10]},
    # alternative combinations can be added with more dictionaries
    # {}
]

rf = RandomForestRegressor()
grid_search = GridSearchCV(rf, parameters_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True, n_jobs=-1)

grid_search.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid=[{'max_depth': [None, 5, 10],
#                           'min_samples_leaf': [1, 3, 5],
#                           'n_estimators': [10, 100]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'max_depth': None, 'min_samples_leaf': 3, 'n_estimators': 100}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# 52524.54633830347 {'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 10}
# 50184.999518317556 {'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 100}
# 52120.33021357614 {'max_depth': None, 'min_samples_leaf': 3, 'n_estimators': 10}
# 50161.61838981445 {'max_depth': None, 'min_samples_leaf': 3, 'n_estimators': 100}
# 52182.81884227268 {'max_depth': None, 'min_samples_leaf': 5, 'n_estimators': 10}
# 50740.24697596604 {'max_depth': None, 'min_samples_leaf': 5, 'n_estimators': 100}
# 64185.88686289727 {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 10}
# 63718.03650963162 {'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 100}
# 64152.72262302475 {'max_depth': 5, 'min_samples_leaf': 3, 'n_estimators': 10}
# 63761.374410179 {'max_depth': 5, 'min_samples_leaf': 3, 'n_estimators': 100}
# 64249.836508878194 {'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 10}
# 63700.09114157902 {'max_depth': 5, 'min_samples_leaf': 5, 'n_estimators': 100}
# 54194.825341730604 {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 10}
# 52876.39508575684 {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 53975.37021347407 {'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 10}
# 52752.00047537187 {'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 100}
# 53962.23107733218 {'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 10}
# 52724.85013462613 {'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 100}

# %%
tuned_rf = grid_search.best_estimator_

rf_pred = tuned_rf.predict(test_X)
rf_mse = mean_squared_error(test_y, rf_pred)
rf_rmse = np.sqrt(rf_mse)
print(f'Tuned random forest RMSE: {rf_rmse}')
# Out:
# Tuned random forest RMSE: 50364.91282404292

# %% [markdown]
# **Randomized search**:

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, norm, randint

distributions = [
    {'n_estimators': randint(10, 100), 'min_samples_leaf': randint(1, 10), 'max_depth': [None, 10]},
    # alternative combinations can be added with more dictionaries
    # {}
]

rf = RandomForestRegressor()
rndm_seach = RandomizedSearchCV(rf, distributions, n_iter = 20, cv=5, scoring="neg_mean_squared_error", 
                           return_train_score=True, n_jobs=-1, )

rndm_seach.fit(train_X, train_y)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=20, n_jobs=-1,
#                    param_distributions=[{'max_depth': [None, 10],
#                                          'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fd534747210>,
#                                          'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fd534747690>}],
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='neg_mean_squared_error',
#                    verbose=0)

# %%
rndm_seach.best_params_
# Out:
# {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 67}

# %%
cvres = rndm_seach.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# 50727.130960739065 {'max_depth': None, 'min_samples_leaf': 3, 'n_estimators': 34}
# 50666.63832259093 {'max_depth': None, 'min_samples_leaf': 4, 'n_estimators': 52}
# 51132.890625863925 {'max_depth': None, 'min_samples_leaf': 6, 'n_estimators': 44}
# 53003.691656093026 {'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 65}
# 50968.69118494994 {'max_depth': None, 'min_samples_leaf': 6, 'n_estimators': 50}
# 50097.12162704181 {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 67}
# 52970.662130135905 {'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 30}
# 53082.43218222372 {'max_depth': 10, 'min_samples_leaf': 1, 'n_estimators': 49}
# 52856.43215377269 {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 60}
# 52955.79385857344 {'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 50}
# 52681.515586345915 {'max_depth': 10, 'min_samples_leaf': 4, 'n_estimators': 92}
# 53402.54467956825 {'max_depth': 10, 'min_samples_leaf': 3, 'n_estimators': 15}
# 53032.898556251486 {'max_depth': 10, 'min_samples_leaf': 2, 'n_estimators': 35}
# 50503.86626322612 {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 43}
# 53267.20890720165 {'max_depth': 10, 'min_samples_leaf': 9, 'n_estimators': 40}
# 50415.098492432306 {'max_depth': None, 'min_samples_leaf': 2, 'n_estimators': 45}
# 51235.245174177326 {'max_depth': None, 'min_samples_leaf': 8, 'n_estimators': 71}
# 52977.77312953637 {'max_depth': 10, 'min_samples_leaf': 6, 'n_estimators': 83}
# 51899.59965309381 {'max_depth': None, 'min_samples_leaf': 4, 'n_estimators': 11}
# 53017.75667124516 {'max_depth': 10, 'min_samples_leaf': 7, 'n_estimators': 37}
